# %%
x=5
print(x)
# Out:
# 5

# %%
print("hello world",type(x))
# Out:
# hello world <class 'int'>

# %%
x=2
hex(id(x))
# Out:
# '0xb370c8'

# %%
x=5 #this is integer variable

# %%
name="dahab"
age=21
course_name="ml diploma"
# print("my name is {},my age is {}".format("dahab",21))
output = f"my name is {name}, my age is {age}, course_name is {course_name}"
print(output)
# Out:
# my name is dahab, my age is 21, course_name is ml diploma

# %%
x={"k1":"depi","k2":"ml"}
print(type(x))
# Out:
# <class 'dict'>

# %%
name = "DEPI for machine learning"
print(type(name))
print (name)
print(name[3])
print(name[-2])
print(name[5:8:1])
print(name[-6:-1:1])
# Out:
# <class 'str'>
# DEPI for machine learning
# I
# n
# for
# arnin

# %%
x=5
y=6
x
print(x)
y
# Out:
# 5
# 6

# %%
name ="depi for ml"
capital = name.upper()
print(capital)
print(capital.lower())
# Out:
# DEPI FOR ML
# depi for ml

# %%
name = "depi for everyone"
print(name.capitalize())
# Out:
# Depi for everyone

# %%
print(name.title())
# Out:
# Depi For Everyone

# %%
name ="depi learning for all learning "
print(name.count("learning"))
# Out:
# 2

# %%
name ="depi learning for all learning "
print(name.split())
# Out:
# ['depi', 'learning', 'for', 'all', 'learning']

# %%
tokens = ["my","name","is","dahab"]
sent = ' '.join(tokens)
print(sent)
# Out:
# my name is dahab

# %%
name = "depi for everyone"
print(name.startswith("for"))
# Out:
# False

# %%
print("welcome \n to depi")
# Out:
# welcome
#  to depi

# %%
print("this is \"depi\" diploma")
# Out:
# this is "depi" diploma

# %%
print("hello\b depi")
# Out:
# hell depi

# %%
my_string="0123456789"
print(my_string[-2:-6:-2])
# Out:
# 86
